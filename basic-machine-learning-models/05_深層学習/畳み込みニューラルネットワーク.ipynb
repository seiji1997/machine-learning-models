# %% [markdown]
# # 畳み込みニューラルネットワーク

# %% [markdown]
# # ドライブのマウント

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/My Drive/machine-learning-models/05_深層学習"
# Out:
# /content/drive/My Drive/machine-learning-models/05_深層学習

# %% [markdown]
# ## ライブラリのインポート

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## データの前処理

# %% [markdown]
# ## 訓練用データセットの前処理

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 2033 images belonging to 2 classes.

# %% [markdown]
# ## テスト用データセットの前処理

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 0 images belonging to 2 classes.

# %% [markdown]
# # 畳み込みニューラルネットワークの構築

# %% [markdown]
# ## イニシャライズ

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# ## 畳み込み

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))

# %% [markdown]
# ## プーリング

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ## 層の追加

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ## Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# ## 出力層の追加

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# # モデルの訓練

# %% [markdown]
# ## モデルのコンパイル

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ## 訓練用データセットを使ったモデルの訓練

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# 64/64 [==============================] - 22s 324ms/step - loss: 0.0133 - accuracy: 0.9843
# Epoch 2/25
# 64/64 [==============================] - 22s 342ms/step - loss: 2.7614e-11 - accuracy: 1.0000
# Epoch 3/25
# 64/64 [==============================] - 19s 303ms/step - loss: 3.2772e-12 - accuracy: 1.0000
# Epoch 4/25
# 64/64 [==============================] - 21s 323ms/step - loss: 4.1295e-12 - accuracy: 1.0000
# Epoch 5/25
# 64/64 [==============================] - 20s 307ms/step - loss: 3.8929e-12 - accuracy: 1.0000
# Epoch 6/25
# 64/64 [==============================] - 24s 372ms/step - loss: 6.7361e-12 - accuracy: 1.0000
# Epoch 7/25
# 64/64 [==============================] - 20s 306ms/step - loss: 1.8300e-11 - accuracy: 1.0000
# Epoch 8/25
# 64/64 [==============================] - 22s 337ms/step - loss: 2.5829e-12 - accuracy: 1.0000
# Epoch 9/25
# 64/64 [==============================] - 20s 308ms/step - loss: 1.0605e-11 - accuracy: 1.0000
# Epoch 10/25
# 64/64 [==============================] - 20s 317ms/step - loss: 1.1286e-11 - accuracy: 1.0000
# Epoch 11/25
# 64/64 [==============================] - 21s 322ms/step - loss: 1.4536e-11 - accuracy: 1.0000
# Epoch 12/25
# 64/64 [==============================] - 21s 334ms/step - loss: 8.3456e-12 - accuracy: 1.0000
# Epoch 13/25
# 64/64 [==============================] - 20s 310ms/step - loss: 3.0117e-12 - accuracy: 1.0000
# Epoch 14/25
# 64/64 [==============================] - 20s 309ms/step - loss: 5.9564e-12 - accuracy: 1.0000
# Epoch 15/25
# 64/64 [==============================] - 23s 365ms/step - loss: 1.1365e-11 - accuracy: 1.0000
# Epoch 16/25
# 64/64 [==============================] - 20s 309ms/step - loss: 3.1933e-12 - accuracy: 1.0000
# Epoch 17/25
# 64/64 [==============================] - 22s 338ms/step - loss: 4.2550e-11 - accuracy: 1.0000
# Epoch 18/25
# 64/64 [==============================] - 21s 320ms/step - loss: 2.4024e-11 - accuracy: 1.0000
# Epoch 19/25
# 64/64 [==============================] - 21s 319ms/step - loss: 1.6197e-11 - accuracy: 1.0000
# Epoch 20/25
# 64/64 [==============================] - 21s 333ms/step - loss: 4.7076e-12 - accuracy: 1.0000
# Epoch 21/25
# 64/64 [==============================] - 22s 335ms/step - loss: 3.5478e-12 - accuracy: 1.0000
# Epoch 22/25
# 64/64 [==============================] - 20s 317ms/step - loss: 1.7355e-11 - accuracy: 1.0000
# Epoch 23/25
# 64/64 [==============================] - 21s 323ms/step - loss: 1.2143e-11 - accuracy: 1.0000
# Epoch 24/25
# 64/64 [==============================] - 20s 313ms/step - loss: 1.1958e-11 - accuracy: 1.0000
# Epoch 25/25
# 64/64 [==============================] - 21s 333ms/step - loss: 1.1014e-11 - accuracy: 1.0000

# %% [markdown]
# # 結果の予測

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
test_image = image.load_img('dataset/single_prediction/cat_or_dog_2.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 [==============================] - 0s 115ms/step

# %%
print(prediction)
# Out:
# dog
