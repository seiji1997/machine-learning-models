# %% [markdown]
# <a href="https://colab.research.google.com/github/seiji0203/Machine-Learning-Models/blob/master/%E4%B8%BB%E6%88%90%E5%88%86%E5%88%86%E6%9E%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 主成分分析

# %%
# モジュールのインポート
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
bc = load_breast_cancer()
df = pd.DataFrame(data=bc.data, columns=bc.feature_names)

# %%
df
# Out:
#      mean radius  mean texture  ...  worst symmetry  worst fractal dimension
# 0          17.99         10.38  ...          0.4601                  0.11890
# 1          20.57         17.77  ...          0.2750                  0.08902
# 2          19.69         21.25  ...          0.3613                  0.08758
# 3          11.42         20.38  ...          0.6638                  0.17300
# 4          20.29         14.34  ...          0.2364                  0.07678
# ..           ...           ...  ...             ...                      ...
# 564        21.56         22.39  ...          0.2060                  0.07115
# 565        20.13         28.25  ...          0.2572                  0.06637
# 566        16.60         28.08  ...          0.2218                  0.07820
# 567        20.60         29.33  ...          0.4087                  0.12400
# 568         7.76         24.54  ...          0.2871                  0.07039
#
# [569 rows x 30 columns]

# %%
df.describe()
# Out:
#        mean radius  mean texture  ...  worst symmetry  worst fractal dimension
# count   569.000000    569.000000  ...      569.000000               569.000000
# mean     14.127292     19.289649  ...        0.290076                 0.083946
# std       3.524049      4.301036  ...        0.061867                 0.018061
# min       6.981000      9.710000  ...        0.156500                 0.055040
# 25%      11.700000     16.170000  ...        0.250400                 0.071460
# 50%      13.370000     18.840000  ...        0.282200                 0.080040
# 75%      15.780000     21.800000  ...        0.317900                 0.092080
# max      28.110000     39.280000  ...        0.663800                 0.207500
#
# [8 rows x 30 columns]

# %%
df.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# dtype: int64

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(df.corr(), annot=True, square=True)
plt.show()

# %% [markdown]
# # 前処理

# %%
scaler = StandardScaler()
scaler.fit(df)
X_scaled = scaler.transform(df)
pd.DataFrame(X_scaled)
# Out:
#            0         1         2   ...        27        28        29
# 0    1.097064 -2.073335  1.269934  ...  2.296076  2.750622  1.937015
# 1    1.829821 -0.353632  1.685955  ...  1.087084 -0.243890  0.281190
# 2    1.579888  0.456187  1.566503  ...  1.955000  1.152255  0.201391
# 3   -0.768909  0.253732 -0.592687  ...  2.175786  6.046041  4.935010
# 4    1.750297 -1.151816  1.776573  ...  0.729259 -0.868353 -0.397100
# ..        ...       ...       ...  ...       ...       ...       ...
# 564  2.110995  0.721473  2.060786  ...  1.629151 -1.360158 -0.709091
# 565  1.704854  2.085134  1.615931  ...  0.733827 -0.531855 -0.973978
# 566  0.702284  2.045574  0.672676  ...  0.414069 -1.104549 -0.318409
# 567  1.838341  2.336457  1.982524  ...  2.289985  1.919083  2.219635
# 568 -1.808401  1.221792 -1.814389  ... -1.745063 -0.048138 -0.751207
#
# [569 rows x 30 columns]

# %%
pca = PCA()
pca.fit(X_scaled)
X_pca = pca.transform(X_scaled)

# 第１主成分と第２主成分をそれぞれ横軸と縦軸にしてPlot
plt.scatter(X_pca[:,0], X_pca[:,1])
plt.show()

# %%
# 寄与率(寄与率は主成分の分散を、元の変数の分散の合計割った値, 主成分の分散の合計 = 元の変数の分散の合計 となるので、寄与率の合計は１)
pca.explained_variance_ratio_
# Out:
# array([4.42720256e-01, 1.89711820e-01, 9.39316326e-02, 6.60213492e-02,
#        5.49576849e-02, 4.02452204e-02, 2.25073371e-02, 1.58872380e-02,
#        1.38964937e-02, 1.16897819e-02, 9.79718988e-03, 8.70537901e-03,
#        8.04524987e-03, 5.23365745e-03, 3.13783217e-03, 2.66209337e-03,
#        1.97996793e-03, 1.75395945e-03, 1.64925306e-03, 1.03864675e-03,
#        9.99096464e-04, 9.14646751e-04, 8.11361259e-04, 6.01833567e-04,
#        5.16042379e-04, 2.72587995e-04, 2.30015463e-04, 5.29779290e-05,
#        2.49601032e-05, 4.43482743e-06])

# %%
# 寄与率の途中和を確認
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.44272026, 0.63243208, 0.72636371, 0.79238506, 0.84734274,
#        0.88758796, 0.9100953 , 0.92598254, 0.93987903, 0.95156881,
#        0.961366  , 0.97007138, 0.97811663, 0.98335029, 0.98648812,
#        0.98915022, 0.99113018, 0.99288414, 0.9945334 , 0.99557204,
#        0.99657114, 0.99748579, 0.99829715, 0.99889898, 0.99941502,
#        0.99968761, 0.99991763, 0.99997061, 0.99999557, 1.        ])

# %%
# 第一主成分と第二主成分を正解ラベルで色分けして表示
index_malignant = np.where(bc.target == 0)
index_benign = np.where(bc.target == 1)
plt.scatter(X_pca[index_malignant, 0], X_pca[index_malignant, 1], label = 'malignant')
plt.scatter(X_pca[index_benign, 0], X_pca[index_benign, 1], label = 'benign')
plt.show()

# %%
# 3成分
ds = load_breast_cancer()
X_scaled = StandardScaler().fit_transform(ds.data)
df = pd.DataFrame(X_scaled, columns=ds.feature_names)
 
pca = PCA(n_components=3)
pca.fit(df)
 
print("Components:\n{}".format(pca.components_))
# Out:
# Components:
# [[ 0.21890244  0.10372458  0.22753729  0.22099499  0.14258969  0.23928535
#    0.25840048  0.26085376  0.13816696  0.06436335  0.20597878  0.01742803
#    0.21132592  0.20286964  0.01453145  0.17039345  0.15358979  0.1834174
#    0.04249842  0.10256832  0.22799663  0.10446933  0.23663968  0.22487053
#    0.12795256  0.21009588  0.22876753  0.25088597  0.12290456  0.13178394]
#  [-0.23385713 -0.05970609 -0.21518136 -0.23107671  0.18611302  0.15189161
#    0.06016536 -0.0347675   0.19034877  0.36657547 -0.10555215  0.08997968
#   -0.08945723 -0.15229263  0.20443045  0.2327159   0.19720728  0.13032156
#    0.183848    0.28009203 -0.21986638 -0.0454673  -0.19987843 -0.21935186
#    0.17230435  0.14359317  0.09796411 -0.00825724  0.14188335  0.27533947]
#  [-0.00853115  0.06455006 -0.00931413  0.0286996  -0.10429118 -0.0740915
#    0.00273384 -0.02556378 -0.04023995 -0.02257443  0.26848137  0.37463347
# ...

# %%
print("Explained :{}".format(pca.explained_variance_ratio_))
# Out:
# Explained :[0.44272026 0.18971182 0.09393163]

# %% [markdown]
# 寄与率は第1主成分が44%、第2主成分が19%、第3主成分が9%

# %%
plt.matshow(pca.components_, cmap='seismic')
plt.yticks([0, 1, 2], ["Component-1", "Component-2", "Comoponent-3"])
plt.colorbar()
plt.xticks(range(len(ds.feature_names)),
    ds.feature_names, rotation=60, ha='left')
plt.xlabel("Feature")
plt.ylabel("Principal components")
 
plt.show()

# %% [markdown]
# 第1主成分は全ての特徴量がプラス方向で寄与
